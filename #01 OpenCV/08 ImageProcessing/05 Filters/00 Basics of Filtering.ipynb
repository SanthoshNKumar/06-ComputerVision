# %%
'''
Image Filtering:
- Image filtering is the process of modifying an image by changing its shades or color of the pixel. 
  It is also used to increase brightness and contrast. 
- Image filtering is a technique used to tweak the images in terms of size, shape, colour, depth, smoothness etc

Filters Available in OpenCV
    - 2D Convolution
        - Filter2D
    
    - Image Blurring (Image Smoothing)
        - Smoothing Linear Filters
            - Average Filters
            - Gaussian Filters
        - Smooting Non Linear Filters
            - Median Filtering
            - Bilateral Filtering
        
    - Morphological Filters
        - Erosion
        - Dilation
        - Opening
        - Closing
        - Morphological Gradient
        - Top hat/white hat and black hat
        
    - Sharpening Filters
        - The Laplacian — Second Derivative
        - The Gradient — First Derivative
        - Sobel operator — Using the Gradient

# %%
'''
Spatial Filtering technique is used directly on pixels of an image.

# %% [markdown]
# ![filters.png](attachment:filters.png)

# %%
'''
How Gaussian Smooting Works:
    - The Gaussian outputs a `weighted average' of each pixel's neighborhood, with the average weighted more towards the 
      value of the central pixels.
    - the Gaussian Filter blurs an image with a bell shape represented by its normal distribution
