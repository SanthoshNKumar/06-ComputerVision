# %%
'''
Forward Propagation
    - During the forward propagation process, we randomly initialized the weights, biases and filters.
    - These values are treated as parameters from the convolutional neural network algorithm. 
    - In the backward propagation process, the model tries to update the parameters such that the overall predictions 
      are more accurate.
    - Updating Parameter
        - new_parameter = old_parameter - (learning_rate * gradient_of_parameter)

# %%
'''
Note : Weights are the values in Filters which needs to be updated

# %%
'''
How Forward Propagtaion works

# %% [markdown]
# ![CNN%20Forward%20Propagation.png](attachment:CNN%20Forward%20Propagation.png)

# %%
'''
Understanding How Fowward and Backward Propagation works

# %%
'''
1.The convolution operation can be written as described in the figure below.

# %% [markdown]
# ![CNN_Output_Calculation_01.JPG](attachment:CNN_Output_Calculation_01.JPG)

# %% [markdown]
# ![CNN_Output_Calculation_02.JPG](attachment:CNN_Output_Calculation_02.JPG)

# %%
'''
Calculate the gradients of filter ‘F’ with respect to the error ‘E’

# %% [markdown]
# ![CNN_Output_Calculation_03.JPG](attachment:CNN_Output_Calculation_03.JPG)

# %% [markdown]
# ![CNN_Output_Calculation_04.JPG](attachment:CNN_Output_Calculation_04.JPG)

# %%
'''
Now, the above computation can be obtained by a different type of convolution operation known as full convolution.

In order to obtain the gradients of the input matrix we need to rotate the filter by 180 degree and calculate the full 
convolution of the rotated filter by the gradients of the output with respect to error

# %% [markdown]
# ![CNN_Output_Calculation_05.JPG](attachment:CNN_Output_Calculation_05.JPG)

# %%
'''
Understanding how weights are updated in 'MaxPooling' layer during back propagation
    - First know the position(Location or Mask) of the original weights and update with new value based on loss or error on 
      the same position.
    - In back propagation we put highest integer on the respected postion and rest will be zero value

# %%
'''
What are initlizers used in back Propagation in CNN Back Propagation
    - He Initiaization

# %%
'''
Things to consider while Babck Propagation and Building CNN
    - Values of Bias
    - Values of Filters
    - Values of Weights
    - Activation functions
