# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Moving Model to Production
# Copy below the Folder and files on Destination where you to Inference the model

# %% [markdown]
# ![yoloV5_5.JPG](attachment:yoloV5_5.JPG)

# %%
'''
- clone Yolo V5 
    - !git clone https://github.com/ultralytics/yolov5
    
- Move the above the files using below the command
    - %cp -r models /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference
    - %cp -r utils /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference
    - %cp detect.py /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference
    - %cp requirements.txt /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference

# %%
# Change the directory
# %cd /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference
# Out:
# /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference

# %%
# Model inferencing

# !python detect.py --source ../Traffic_dataset/images/test/00076.jpg  --weights ../weights/best.pt --conf 0.25
# Out:
# detect: weights=['../weights/best.pt'], source=../Traffic_dataset/images/test/00076.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-16 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/My Drive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Traffic_dataset/images/test/00076.jpg: 384x640 1 speed limit, 1 yield, Done. (0.031s)
# Speed: 0.5ms pre-process, 30.5ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
import os
os.getcwd()
# Out:
# '/content/drive/My Drive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/Inference'

# %%
from IPython.display import Image #this is to render predictions

Image(filename='./runs/detect/exp/00076.jpg', width=1000)
