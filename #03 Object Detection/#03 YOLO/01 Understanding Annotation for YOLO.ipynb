# %%
'''
  Annotation format for YOLO 
    - YOLO v5 expects annotations for each image in form of a .txt file
    - Where each line of the text file describes a bounding box
    - Each row is (class,x_center,y_center,width,height)
    - Class numbers are zero-indexed (start from 0)

# %% [markdown]
# ![yolo%20annottaion1-2.JPG](attachment:yolo%20annottaion1-2.JPG)

# %% [markdown]
# ![yolo%20annottaion.JPG](attachment:yolo%20annottaion.JPG)

# %%
# convertion of .csv format to Yolo (.txt)

# %% [markdown]
# ![CSV%20format.JPG](attachment:CSV%20format.JPG)
