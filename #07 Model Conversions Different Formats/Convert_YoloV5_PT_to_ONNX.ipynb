# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd /content/yolov5/data
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9966, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 9966 (delta 15), reused 18 (delta 9), pack-reused 9928
# Receiving objects: 100% (9966/9966), 10.30 MiB | 22.93 MiB/s, done.
# Resolving deltas: 100% (6904/6904), done.
#      |████████████████████████████████| 596 kB 7.3 MB/s
# /content/yolov5/data

# %% [markdown]
# ![yoloV5_6.JPG](attachment:yoloV5_6.JPG)

# %%
# %cd /content/yolov5

# !pip install onnx>=1.7.0 # for ONNX export
# !pip install coremltools==4.0 # for CoreML export
# Out:
# /content/yolov5
# ...
#      |████████████████████████████████| 3.4 MB 7.9 MB/s
# ...
#   Created wheel for attr: filename=attr-0.3.1-py3-none-any.whl size=2457 sha256=8814b435c8ac6558e07cf2d12f839277756aee4ec36996cc1a9374894f4a256e
#   Stored in directory: /root/.cache/pip/wheels/3b/5d/58/41fbe92f47031641008bd8559ee89e58bf0f123f9c18dea1cb
# Successfully built attr
# ...

# %%
'''
# !python /content/yolov5/export.py 
--weights /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/weights/best.pt 
--img 416 
--batch 1 # export at 640x640 with batch size 1

'''
# !python /content/yolov5/export.py --weights /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/weights/best.pt --img 416 --batch 1 # export at 640x640 with batch size 1
# Out:
# ...
# export: data=data/coco128.yaml, weights=/content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/weights/best.pt, imgsz=[416], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=13, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v6.0-94-g47fac9f torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/ComputerVision/dataset/ObjectDetection/YOLO/yolov5/weights/best.pt (14.3 MB)
#
# TorchScript: starting export with torch 1.10.0+cu111...
# ...

# %% [markdown]
# ![yoloV5_7.jpg](attachment:yoloV5_7.jpg)
